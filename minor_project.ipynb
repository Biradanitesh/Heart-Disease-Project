# %% [markdown]
# <a href="https://colab.research.google.com/github/Biradanitesh/Heart-Disease-Project/blob/main/minor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/heart (1).csv')

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
X=df.drop("target",axis="columns")
Y=df['target']

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print(training_data_accuracy)
# Out:
# 0.8512396694214877

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print(test_data_accuracy)
# Out:
# 0.819672131147541

# %%
input_data=(57,0,0,140,241,0,1,123,1,0.2,1,0,3)
input_data_as_numpy_array=np.asarray(input_data)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshaped)
print(prediction)
if(prediction[0]==0):
  print('The person doesnot have a Heart Disease')
else:
  print('The person has Heart Disease')
# Out:
# [0]
# The person doesnot have a Heart Disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#specify the architecture
from keras.layers import Dense
from keras.models import Sequential

# %%
model=Sequential()
model.add(Dense(100,activation="relu",input_shape=(13,)))
model.add(Dense(200,activation="relu"))
model.add(Dense(1))

# %%
#compile the model
model.compile(loss="mean_squared_error",optimizer="adam")

# %%
#fit the model
model.fit(X,Y,epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 3ms/step - loss: 147.1869
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.2204
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 11.9710
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.7188
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0049
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0335
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5422
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3921
# Epoch 9/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3533
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3794
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3830
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2633
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2690
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2280
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2209
# Epoch 16/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2590
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2440
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2162
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2769
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2138
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2330
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2091
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1894
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1893
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1977
# Epoch 26/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2060
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2214
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1957
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2068
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1937
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1794
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1936
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1909
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2138
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1978
# Epoch 36/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2061
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2266
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3150
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1838
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2295
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1891
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1736
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1630
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2027
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2343
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1954
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1500
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1774
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2547
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2345
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2168
# Epoch 52/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2130
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3172
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2654
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1999
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1700
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1644
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1691
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1697
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1798
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1822
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2244
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2589
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2617
# Epoch 65/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1753
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1701
# Epoch 67/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1580
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1389
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1407
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1457
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1861
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1595
# Epoch 73/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1591
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2085
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2001
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1879
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2568
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2016
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2899
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1837
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1360
# Epoch 82/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1482
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1532
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1795
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2309
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1550
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1298
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1535
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1859
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1601
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1771
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2566
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4177
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2758
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2103
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1746
# Epoch 97/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1382
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1634
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2168
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2327

# %%
#predict using the model
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
data=pd.DataFrame({"age":[40],"sex":[1],"cp":[2],"trestbps":[135],"chol":[224],"fbs":[0],"restecg":[1],"thalach":[172],"exang":[0],"oldpeak":[2.2],"slope":[0],"ca":[0],"thal":[2]})

# %%
data
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   40    1   2       135   224    0        1      172      0      2.2      0
#
#    ca  thal
# 0   0     2

# %%
model.predict(data)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# array([[1.0336071]], dtype=float32)
